# %% [markdown]
# <a href="https://colab.research.google.com/github/Modah237/Flickr_30K_Categories/blob/main/5000K_predicted_categoies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os

# Load the pre-trained model
model = keras.applications.resnet50.ResNet50(weights='imagenet', include_top=True)

# Define the image preprocessing function
def preprocess_image(img_path):
    img = keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return keras.applications.resnet50.preprocess_input(img_array)

# Classify the images
folder_path = '/content/drive/MyDrive/FLickr_5K/'
categories = {}  # dictionary to store the categories and their respective counts
with open('predicted_categories.txt', 'w') as f:
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = preprocess_image(img_path)
        preds = model.predict(img)
        decoded_preds = keras.applications.resnet50.decode_predictions(preds, top=1)[0]
        category = decoded_preds[0][1]  # get the category label with the highest probability
        f.write(f'{img_name}: {category}\n')
        categories[category] = categories.get(category, 0) + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 159ms/step
# ...
# ...
# 1/1 [==============================] - 0s 288ms/step
#
# Category counts:
# golden_retriever: 7
# ski: 81
# curly-coated_retriever: 4
# drumstick: 8
# barbershop: 38
# harmonica: 15
# German_short-haired_pointer: 4
# sulphur-crested_cockatoo: 2
# parachute: 36
# menu: 2
# pajama: 20
# Shetland_sheepdog: 3
# pickup: 3
# recreational_vehicle: 6
# toy_terrier: 2
# Labrador_retriever: 13
# malinois: 8
# vestment: 29
# miniskirt: 38
# cloak: 9
# Bernese_mountain_dog: 6
# padlock: 4
# stupa: 7
# alp: 29
# Scotch_terrier: 1
# shield: 12
# park_bench: 29
# sunglass: 10
# mountain_bike: 92
# microphone: 16
# Ibizan_hound: 8
# Irish_terrier: 11
# Great_Dane: 4
# jack-o'-lantern: 3
# lipstick: 4
# bathtub: 4
# German_shepherd: 8
# ice_cream: 2
# cab: 18
# sweatshirt: 3
# Norwich_terrier: 2
# sliding_door: 11
# backpack: 5
# syringe: 10
# balloon: 11
# wig: 27
# kelpie: 3
# ...

# %%
# Print the categories and their respective counts
print('\nCategory counts:')
for category, count in categories.items():
    print(f'{category}: {count}')
# Out:
# Category counts:
# golden_retriever: 7
# ski: 81
# curly-coated_retriever: 4
# drumstick: 8
# barbershop: 38
# harmonica: 15
# German_short-haired_pointer: 4
# sulphur-crested_cockatoo: 2
# parachute: 36
# menu: 2
# pajama: 20
# Shetland_sheepdog: 3
# pickup: 3
# recreational_vehicle: 6
# toy_terrier: 2
# Labrador_retriever: 13
# malinois: 8
# vestment: 29
# miniskirt: 38
# cloak: 9
# Bernese_mountain_dog: 6
# padlock: 4
# stupa: 7
# alp: 29
# Scotch_terrier: 1
# shield: 12
# park_bench: 29
# sunglass: 10
# mountain_bike: 92
# microphone: 16
# Ibizan_hound: 8
# Irish_terrier: 11
# Great_Dane: 4
# jack-o'-lantern: 3
# lipstick: 4
# bathtub: 4
# German_shepherd: 8
# ice_cream: 2
# cab: 18
# sweatshirt: 3
# Norwich_terrier: 2
# sliding_door: 11
# backpack: 5
# syringe: 10
# balloon: 11
# wig: 27
# kelpie: 3
# wire-haired_fox_terrier: 4
# groenendael: 7
# robin: 2
# Staffordshire_bullterrier: 5
# freight_car: 2
# lakeside: 25
# washer: 3
# standard_poodle: 11
# warthog: 5
# ...

# %% [markdown]
# Example 1

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os

# Load the pre-trained model
model = keras.applications.resnet50.ResNet50(weights='imagenet', include_top=True)

# Define the number of categories based on the number of classes in the pretrained model
num_categories = len(model.predict(np.zeros((1, 224, 224, 3))))
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
def preprocess_image(img_path):
    img = keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return keras.applications.resnet50.preprocess_input(img_array)

# %%
folder_path = '/content/drive/MyDrive/FLickr_5K/'
categories = {}  # dictionary to store the categories and their respective counts
for img_name in os.listdir(folder_path):
    img_path = os.path.join(folder_path, img_name)
    img = preprocess_image(img_path)
    preds = model.predict(img)
    decoded_preds = keras.applications.resnet50.decode_predictions(preds, top=1)[0]
    category = decoded_preds[0][1]  # get the category label with the highest probability
    print(f'Image: {img_name} - Category: {category}')
    categories[category] = categories.get(category, 0) + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 182ms/step
# Image: 4770236023.jpg - Category: torch
# 1/1 [==============================] - 0s 184ms/step
# Image: 4768602434.jpg - Category: oboe
# 1/1 [==============================] - 0s 169ms/step
# Image: 4768834139.jpg - Category: prayer_rug
# 1/1 [==============================] - 0s 171ms/step
# Image: 4764880358.jpg - Category: motor_scooter
# 1/1 [==============================] - 0s 168ms/step
# Image: 4769586761.jpg - Category: swing
# 1/1 [==============================] - 0s 177ms/step
# Image: 4769459188 (1).jpg - Category: pretzel
# 1/1 [==============================] - 0s 187ms/step
# Image: 4769459188.jpg - Category: pretzel
# 1/1 [==============================] - 0s 181ms/step
# Image: 4770070628 (1).jpg - Category: jinrikisha
# 1/1 [==============================] - 0s 174ms/step
# Image: 4767620642.jpg - Category: pole
# ...

# %%
# Print the categories and their respective counts
print('\nCategory counts:')
for category, count in categories.items():
    print(f'{category}: {count}')
# Out:
# Category counts:
# golden_retriever: 7
# ski: 81
# curly-coated_retriever: 4
# drumstick: 8
# barbershop: 38
# harmonica: 15
# German_short-haired_pointer: 4
# sulphur-crested_cockatoo: 2
# parachute: 36
# menu: 2
# pajama: 20
# Shetland_sheepdog: 3
# pickup: 3
# recreational_vehicle: 6
# toy_terrier: 2
# Labrador_retriever: 13
# malinois: 8
# vestment: 29
# miniskirt: 38
# cloak: 9
# Bernese_mountain_dog: 6
# padlock: 4
# stupa: 7
# alp: 29
# Scotch_terrier: 1
# shield: 12
# park_bench: 29
# sunglass: 10
# mountain_bike: 92
# microphone: 16
# Ibizan_hound: 8
# Irish_terrier: 11
# Great_Dane: 4
# jack-o'-lantern: 3
# lipstick: 4
# bathtub: 4
# German_shepherd: 8
# ice_cream: 2
# cab: 18
# sweatshirt: 3
# Norwich_terrier: 2
# sliding_door: 11
# backpack: 5
# syringe: 10
# balloon: 11
# wig: 27
# kelpie: 3
# wire-haired_fox_terrier: 4
# groenendael: 7
# robin: 2
# Staffordshire_bullterrier: 5
# freight_car: 2
# lakeside: 25
# washer: 3
# standard_poodle: 11
# warthog: 5
# ...
